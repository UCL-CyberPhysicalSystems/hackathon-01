# %% [markdown]
# # Installing dependencies

# %%
# %%time

# !python --version
#tested with 
#python 3.9; 
    #OK
#python3.10.18  
    #OK

#python3.12.3
      # AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
      # [end of output]
# Out:
# Python 3.10.18
# CPU times: user 1.4 ms, sys: 52.5 ms, total: 53.9 ms
# Wall time: 191 ms

# %%
# %%time

# !pip install --upgrade pip setuptools wheel

# #Original dependnecies and their versions # Installed in time: 5min 24s
# !pip install colorama==0.4.6 \
# einops GitPython==3.1.37 gym==0.17.3 h5py \
# hypothesis==6.87.1 imageio imageio-ffmpeg mediapy \
# matplotlib==3.7.2 multiprocess==0.70.15 numpy==1.23.4 omegaconf \
# opencv-python huggingface-hub \
# pandas Pillow pybullet==3.2.5 pyogrio==0.6.0 \
# PyOpenGL==3.1.7 pyparsing==3.0.9 pyproj==3.6.1 \
# pytest==7.4.2 PyYAML==6.0.1 scikit-learn==1.3.0 scipy==1.11.1 sortedcontainers==2.4.0 \
# termcolor==2.4.0 testbook==0.4.2 threadpoolctl==3.2.0 timm==0.9.7 \
# transforms3d==0.4.1 typed-argument-parser==1.10.0 wandb==0.14.2

# !pip install GitPython numpy opencv-python h5py tqdm gym==0.17 typed-argument-parser termcolor GitPython matplotlib pybullet==3.2.5 colorama pandas imageio scipy torch torchvision einops wandb
#Notes: Fail to build gym pybullet because of specific versions


# !pip install GitPython numpy opencv-python h5py tqdm gym typed-argument-parser termcolor GitPython matplotlib pybullet colorama pandas imageio scipy torch torchvision einops wandb
#Notes: Fail to build gym pybullet because of specific versions
# Out:
# Requirement already satisfied: pip in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (25.3)
# Requirement already satisfied: setuptools in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (80.9.0)
# Requirement already satisfied: wheel in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.45.1)
# Requirement already satisfied: GitPython in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (3.1.37)
# Requirement already satisfied: numpy in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (1.23.4)
# Requirement already satisfied: opencv-python in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: h5py in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (3.15.1)
# Requirement already satisfied: tqdm in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: gym in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: typed-argument-parser in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: termcolor in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: matplotlib in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: pybullet in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (3.2.5)
# Requirement already satisfied: colorama in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: pandas in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: imageio in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (2.37.0)
# Requirement already satisfied: scipy in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: torch in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (2.9.0)
# Requirement already satisfied: torchvision in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.24.0)
# Requirement already satisfied: einops in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.8.1)
# Requirement already satisfied: wandb in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (0.14.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from GitPython) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from gym) (1.6.0)
# Requirement already satisfied: future in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (1.0.0)
# Requirement already satisfied: typing-inspect>=0.7.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from typed-argument-parser) (0.9.0)
# Requirement already satisfied: docstring-parser>=0.15 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from typed-argument-parser) (0.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from torch) (3.5.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (8.3.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: psutil>=5.0.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (7.1.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (2.42.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: pathtools in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (1.3.7)
# Requirement already satisfied: setuptools in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (80.9.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from wandb) (4.25.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: six>=1.4.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from typing-inspect>=0.7.1->typed-argument-parser) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages (from jinja2->torch) (3.0.3)
# CPU times: user 37.9 ms, sys: 118 ms, total: 156 ms
# Wall time: 2.26 s

# %% [markdown]
# # Clone Potential Based Diffusion Motion Planning Repo from Github
# ## Installed the Simulated Environment

# %%
# %%time

# !git clone https://github.com/devinluo27/potential-motion-plan-release.git
# %cd potential-motion-plan-release/pb_diff_envs
# !pip install -e .
# !pip list | grep pb
#@markdown - Module not found might be returned because the newly installed package might not be automatically loaded. In this case, please restart this session and directly run from this cell.
# %cd ..
# !pwd
# Out:
# Cloning into 'potential-motion-plan-release'...
# remote: Enumerating objects: 372, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 372 (delta 103), reused 356 (delta 90), pack-reused 0 (from 0)
# Receiving objects: 100% (372/372), 16.32 MiB | 8.56 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %% [markdown]
# # Check Package Installation Status
# # Please Restart session and run from this cell if module not found **

# %%
##
## ** Please Restart session and run from this cell if module not found **
##
import pb_diff_envs.environment
import sys
sys.version
# Out:
# '3.9.24 (main, Oct 14 2025, 21:25:12) \n[Clang 20.1.4 ]'

# %% [markdown]
# ## Download the Pre-trained Model and Maze2D Environment Files From Google Drive

# %%
# %%time

# %cd potential-motion-plan-release/
# !pip install gdown
import gdown
# download demonstration data from Google Drive
gdrive_id_model = '1BS-N3YrEGd9vUp3vC44d0SOlXQFdUW7A' # model [116M Jul  6  2024 model-maze2d-static1-base.zip]
gdown.download(id=gdrive_id_model, quiet=False)
gdrive_id_env = '1eN7Sl6m7NgJn526nZjlryXFn58522pQ6' # env [552M Jul  6  2024 maze2d-static1-base.zip]
gdown.download(id=gdrive_id_env, quiet=False)
# Out:
# [Errno 2] No such file or directory: 'potential-motion-plan-release/'
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential-motion-plan-release
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv/lib/python3.9/site-packages (from requests[socks]->gdown) (2025.10.5)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gdown]
# Successfully installed PySocks-1.7.1 gdown-5.2.0
# Downloading...
# From (original): https://drive.google.com/uc?id=1BS-N3YrEGd9vUp3vC44d0SOlXQFdUW7A
# From (redirected): https://drive.google.com/uc?id=1BS-N3YrEGd9vUp3vC44d0SOlXQFdUW7A&confirm=t&uuid=f76ab6d9-cdbd-4426-99ec-bc243dc21a37
# To: /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential-motion-plan-release/model-maze2d-static1-base.zip
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 121M/121M [00:13<00:00, 8.90MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1eN7Sl6m7NgJn526nZjlryXFn58522pQ6
# From (redirected): https://drive.google.com/uc?id=1eN7Sl6m7NgJn526nZjlryXFn58522pQ6&confirm=t&uuid=4fb22347-4f69-4da8-8775-cc09bb0a3503
# To: /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential-motion-plan-release/maze2d-static1-base.zip
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 578M/578M [01:06<00:00, 8.67MB/s]
# 'maze2d-static1-base.zip'

# %%
#@markdown - Unzip to corresponding locations
# !mv maze2d-static1-base.zip ./pb_diff_envs/pb_diff_envs/
# %cd ./pb_diff_envs/pb_diff_envs/ 
# !unzip maze2d-static1-base.zip -d .
# %cd ../../ #cd potential-motion-plan-release
# !pwd
# !unzip model-maze2d-static1-base.zip -d .
# Out:
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential-motion-plan-release
# Archive:  model-maze2d-static1-base.zip
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/dataset_config.pkl
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/diffusion_config.pkl
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/trainer_config.pkl
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/model_config.pkl
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/render_config.pkl
#  extracting: ./logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/state_1900000.pt

# %% [markdown]
# # Motion Planning

# %%
# !pwd
# %cd potential-motion-plan-release/pb_diff_envs
# Out:
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning/potential-motion-plan-release/pb_diff_envs
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/.venv.python310/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pb_diff_envs.environment
import sys
sys.version
# Out:
# '3.10.18 (main, Sep  2 2025, 14:19:37) [Clang 20.1.4 ]'

# %%
# !pwd
# %cd ../
#cd potential-motion-plan-release
# Out:
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning/potential-motion-plan-release/pb_diff_envs
# /home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning/potential-motion-plan-release

# %%
#@title Initialize and Load Model

import numpy as np
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' ## please on a machine with GPU
import sys
sys.path.append('.')
import torch
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cudnn.deterministic = True
from diffuser.guides.policies import Policy
import diffuser.datasets as datasets
import diffuser.utils as utils
from diffuser.models import GaussianDiffusionPB
from diffuser.guides.policies_compose import PolicyCompose
from datetime import datetime
import os.path as osp
from tqdm import tqdm
from diffuser.utils.jupyter_utils import suppress_stdout

class Parser(utils.Parser):
    config: str = "config/rm2d/rSmaze_nw6_hExt05_exp.py"

# %% [markdown]
# # ---------------------------------- setup ----------------------------------

# %%
## training args
args_train = Parser().parse_args('diffusion', from_jupyter=True)
args = Parser().parse_args('plan', from_jupyter=True)

args.savepath = None # osp.join(args.savepath, sub_dir)
args.load_unseen_maze = True

## load dataset here, dataset is a string: name of the env
print('args.dataset', type(args.dataset), args.dataset)
print('args.dataset_eval', type(args.dataset_eval), args.dataset_eval)
use_normed_wallLoc = args_train.dataset_config.get('use_normed_wallLoc', False)

## use the trained env or eval env
load_unseen_maze = True # args.load_unseen_maze # True False
with suppress_stdout():
    #---------------------------------- loading ----------------------------------#
    from pb_diff_envs.environment.static.maze2d_rand_wgrp_43 import RandRectangleGroup_43
    train_env_list: RandRectangleGroup_43
    train_env_list = datasets.load_environment(args.dataset, is_eval=load_unseen_maze)
    train_normalizer = utils.load_datasetNormalizer(train_env_list.dataset_url, args_train, train_env_list)

    ld_config = dict(env_instance=train_env_list)
    diffusion_experiment = utils.load_potential_diffusion_model(args.logbase, args.dataset, \
                args_train.exp_name, epoch=args.diffusion_epoch, ld_config=ld_config)
    diffusion = diffusion_experiment.ema
# Out:
# module <module 'rSmaze_nw6_hExt05_exp' from '/home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning/potential-motion-plan-release/config/rm2d/rSmaze_nw6_hExt05_exp.py'>
# [ utils/setup ] Reading config: config/rm2d/rSmaze_nw6_hExt05_exp:randSmaze2d_ng3ks25k_ms55nw6_hExt05_v0
# [ utils/setup ] Not using overrides | config: config/rm2d/rSmaze_nw6_hExt05_exp | dataset: randSmaze2d_ng3ks25k_ms55nw6_hExt05_v0
# prefix  diffusion/
# config_fn rSmaze_nw6_hExt05_exp
# horizon H 48
# n_diffusion_steps T 100
# exp_name diffusion/rSmaze_nw6_hExt05_exp_H48_T100
# [ utils/setup ] Setting exp_name to: diffusion/rSmaze_nw6_hExt05_exp_H48_T100
# [ utils/setup ] Saved args to logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/diffusion/rSmaze_nw6_hExt05_exp_H48_T100/args.json
# module <module 'rSmaze_nw6_hExt05_exp' from '/home/mxochicale/repositories/UCL-CyberPhysicalSystems/hackathon-01/notebooks/potential_based_diffusion_motion_planning/potential-motion-plan-release/config/rm2d/rSmaze_nw6_hExt05_exp.py'>
# [ utils/setup ] Reading config: config/rm2d/rSmaze_nw6_hExt05_exp:randSmaze2d_ng3ks25k_ms55nw6_hExt05_v0
# [ utils/setup ] Not using overrides | config: config/rm2d/rSmaze_nw6_hExt05_exp | dataset: randSmaze2d_ng3ks25k_ms55nw6_hExt05_v0
# [ utils/setup ] Lazy fstring | diffusion_loadpath : f:diffusion/H{horizon}_T{n_diffusion_steps} --> diffusion/H48_T100
# prefix  plans/release
# config_fn rSmaze_nw6_hExt05_exp
# horizon H 48
# n_diffusion_steps T 100
# normalizer  LimitsNormalizer
# batch_size b 1
# conditional cond True
# exp_name plans/release_rSmaze_nw6_hExt05_exp_H48_T100_LimitsNormalizer_b1_condTrue
# [ utils/setup ] Setting exp_name to: plans/release_rSmaze_nw6_hExt05_exp_H48_T100_LimitsNormalizer_b1_condTrue
# [ utils/setup ] Saved args to logs/randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0/plans/release_rSmaze_nw6_hExt05_exp_H48_T100_LimitsNormalizer_b1_condTrue/0/args.json
# args.dataset <class 'str'> randSmaze2d-ng3ks25k-ms55nw6-hExt05-v0
# args.dataset_eval <class 'str'> randSmaze2d-ng3ks25k-ms55nw6-hExt05-eval-v0

# %%
#@title Define an Environment
#@markdown - In mode `from_env`, the pre-generated evaluation wall location sets are used. Please specify the set index in `env_id`.
#@markdown - In mode `user_input`, enter your own wall locations in the variable `wloc`.

from diffuser.utils.rm2d_render import RandStaticMazeRenderer
import imageio
np.set_printoptions(precision=3)
## define an env's wall locations
# wloc_source = 'from_env'
wloc_source = 'user_input'
if wloc_source == 'from_env':
    env_id = 17
    wloc = train_env_list.wallLoc_list[env_id]
    print(f'wall locations of env {env_id}:')
    print(train_env_list.wallLoc_list[env_id])
elif wloc_source == 'user_input':
    env_id = 5 # placholder
    ## Our
    wloc = np.array([
        [0.983, 1.844],
        [1.444, 3.904],
        [2.32,  1.612],
        [3.495, 0.713],
        [3.9,   4.307],
        [4.107, 2.546],])

    ## wall size must be fixed
    train_env_list.create_env_by_pos(env_id, wloc, train_env_list.hExt_list[env_id])

# %%
# %%time


# @title Generate Motion Plans
#@markdown - Set the agent's start and goal position in `start` and `goal`.

diffusion: GaussianDiffusionPB
bs = 10
policy = Policy(diffusion, train_normalizer, use_ddim=True)


## choose a start and goal position
start = np.array( [ [ 0.4, 4.7 ] ], dtype=np.float32 ).repeat( bs, 0 )
goal = np.array( [ [4.8, 1.2] ], dtype=np.float32  ).repeat( bs, 0 )

print( start.shape )
wloc_np = wloc # wloc in numpy

wloc_tensor = utils.to_torch(wloc_np).reshape(1, -1).repeat( (bs, 1) )
print( f'wloc_np: ', wloc_np.shape )

## Horizon = 48 By default
cond = {0: start,
        47: goal}

samples = policy(cond, batch_size=-1, wall_locations=wloc_tensor, use_normed_wallLoc=use_normed_wallLoc, return_diffusion=True)

unnm_traj = samples[1].observations
print(f'unnm_traj: {unnm_traj.shape}')


root_dir = 'potential-motion-plan-release/visualization/'
os.makedirs(root_dir, exist_ok=True)
print('traj shape:', unnm_traj.shape)
rd = RandStaticMazeRenderer(train_env_list)
tmp_path = f'{root_dir}/plot_rm2d_base.png'
img = rd.composite( tmp_path, unnm_traj,  np.array([env_id]))
img = imageio.imread(tmp_path)
utils.plt_img(img)
# Out:
# (10, 2)
# wloc_np:  (6, 2)
# conditional_sample shape: (10, 48, 2) walls_loc torch.Size([10, 12])
# 0 torch.Size([10, 2])
# 47 torch.Size([10, 2])
# ddim steps: 10
# unnm_traj: (10, 48, 2)
# traj shape: (10, 48, 2)
# Saved 10 samples to: potential-motion-plan-release/visualization//plot_rm2d_base.png
# <timed exec>:35: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# CPU times: user 1.45 s, sys: 1.54 s, total: 2.99 s
# Wall time: 1.16 s

# %%
# %%time

# @title Render A Single Maze2D Motion Plan
import imageio
from pb_diff_envs.environment.static.rand_maze2d_renderer import RandMaze2DRenderer

lemp_rd = RandMaze2DRenderer(num_walls_c=[len(wloc_np), 0], fig_dpi=300)
hExt = train_env_list.hExt_list[0, 0].tolist() # [0.5, 0.5]
hExts = np.array([hExt,] * len(wloc_np))

path_id = 9
img = lemp_rd.renders( unnm_traj[ path_id ], train_env_list.maze_size, wloc_np , hExts )
print(f'resol: {img.shape}')
# tmp_path = f'./plot_rm2d_base.png'
# imageio.imsave( tmp_path, img )
# utils.plt_img(img, dpi=80)
import mediapy as mpy
mpy.show_image(img, width=300)
# Out:
# resol: (1500, 1500, 4)
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="300" height="300" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>
# CPU times: user 173 ms, sys: 7.29 ms, total: 180 ms
# Wall time: 176 ms

# %%
# %%time

# @title Render A Denoising Video
# Dependencies in local device `sudo apt install ffmpeg`
from pb_diff_envs.environment.static.rand_maze2d_renderer import RandMaze2DRenderer
env = train_env_list.model_list[env_id]

traj_idx = 0 # which traj

x0_perstep = samples[3] # shape: B, n_steps, Horizon, Dim
x0_perstep.shape

n_steps = len(x0_perstep[0]) ## number of denosing steps + 1
trajs_ps = [] ## per-step trajs
imgs_ps = []

mz_renderer = RandMaze2DRenderer(num_walls_c=[30,10], fig_dpi=200)
mz_renderer.up_right = 'empty'
mz_renderer.config['no_draw_traj_line'] = False
mz_renderer.config['no_draw_col_info'] = True # False
# mz_renderer.num_walls_c = [0, 30]

for i_st in range(1, n_steps):
    traj_ps = x0_perstep[traj_idx][i_st] #
    trajs_ps.append(traj_ps)
    ### -----
    env_wlocs = env.wall_locations
    # hExt = plan_env_list.hExt_list[0, 0].tolist()
    # env_hExts = np.concatenate(env.hExt_list_c, axis=0)
    env_hExts = env.wall_hExts
    img = mz_renderer.renders( traj_ps , train_env_list.maze_size, env_wlocs, env_hExts )
    imgs_ps.append(img)


## show the video
print('root_dir:', root_dir)
from diffuser.utils.video import save_images_to_mp4, read_mp4_to_numpy

mp4_name = f'{root_dir}/base_{env_id}.mp4' # {utils.get_time()}
## Save to video
save_images_to_mp4(imgs_ps, mp4_name, fps=15, st_sec=1, end_sec=1)
## load and save
import mediapy as media
from mediapy import show_video, read_video
show_video(read_mp4_to_numpy(mp4_name), fps=10, width=300)
# Out:
# root_dir: potential-motion-plan-release/visualization/
# video_array: (38, 992, 992, 3)
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="300" height="300" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# CPU times: user 1.6 s, sys: 310 ms, total: 1.91 s
# Wall time: 2.62 s
